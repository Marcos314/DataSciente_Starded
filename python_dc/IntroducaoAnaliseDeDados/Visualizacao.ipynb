# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([1,3,5],[2,5,7])
plt.show()

# %%
x = [1,2,3]
y = [3,7,2]

# %%
plt.plot(x,y)
plt.xlabel('Var 1')
plt.ylabel('Var 2')
plt.title('Titulo')
plt.show()

# %%
x2 = [1,2,3]
y2 = [11,12,15]

# %%
plt.plot(x2,y2, label='PrimeiraLinha')
plt.legend()
plt.show()
